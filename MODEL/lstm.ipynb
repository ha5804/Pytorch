# %% [markdown]
# # Simple LSTM Practice
#
# `point`
# - (1) torch를 이용한 모델 설계
# - (2) lstm 작동 과정 이해
# - (3) lstm 데이터 처리 이해
# ---

# %% [markdown]
# ## 1.Problem
#
# - LSTM을 이용하여 주가 예측
# ---
# ## 2.Data Process
#
# - (1): yfinance를 통해 data 로드
# - (2): data tensor 변환
# - (3): sequence data 생성

# %% [markdown]
# ### (1)load data
#
# yfinance를 이용하면 보다 쉽게 data를 사용할 수 있다.
#
# - data.head()를 통해 data 구성 확인(feature, day...)

# %%
import yfinance as yf

data = yf.download("005930.KS", start = "2020-01-01", end = "2024-01-01")

print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price              Close          High           Low          Open    Volume
# Ticker         005930.KS     005930.KS     005930.KS     005930.KS 005930.KS
# Date
# 2020-01-02  47470.902344  48158.886436  47298.906321  47728.896378  12993228
# 2020-01-03  47728.886719  48674.864654  47212.898754  48158.876689  15422255
# 2020-01-06  47728.886719  47814.884713  46954.904772  47212.898754  10278951
# 2020-01-07  47986.898438  48502.886593  47814.902386  47900.900412  10009778
# 2020-01-08  48846.863281  49362.851274  48072.881293  48330.875289  23501171

# %% [markdown]
# ### (2) data tensor 변환
#
# - torch를 이용하여, lstm 모델에 사용할 데이터 tensor변환.
# - torch.tensor(data[features_list])로 변환 가능.
# - data shape 확인 중요 -> dtype 설정 필요.

# %%
import torch

# x = torch.tensor(data[['Open', 'High', 'Low', 'Close', 'Volume']])
#error, dtype 오류

x = torch.tensor(data[['Open','High','Low','Close','Volume']].values,
                 dtype = torch.float32)

print(x.shape)
# Out:
# torch.Size([985, 5])

# %%
seq_length = 5

x_seq = []
y_seq = []

for i in range(len(x) - seq_length):
    x_seq.append(x[i:i+seq_length])
    y_seq.append(x[i+seq_length][3])

x_seq = torch.stack(x_seq)
y_seq = torch.stack(y_seq)
